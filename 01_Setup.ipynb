# %% [markdown]
# ## STEP 1 — Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## STEP 2 — Set Working Directory

# %%
import os

project_path = "/content/drive/MyDrive/Fraud-Detection-Project"

os.chdir(project_path)

print("Current Directory:", os.getcwd())
# Out:
# Current Directory: /content/drive/MyDrive/Fraud-Detection-Project

# %% [markdown]
# ## STEP 3 — Create Subfolders

# %%
folders = ["data", "notebooks", "models", "reports"]

for folder in folders:
    os.makedirs(folder, exist_ok=True)

print("Project folders created successfully!")
# Out:
# Project folders created successfully!

# %% [markdown]
# ## STEP 4 — Download Dataset

# %%
# !pip install kagglehub

# %%
import kagglehub

path = kagglehub.dataset_download("sgpjesus/bank-account-fraud-dataset-neurips-2022")

print("Downloaded to:", path)
# Out:
# ...
# 100%|██████████| 532M/532M [00:18<00:00, 29.5MB/s]
# Extracting files...
# Downloaded to: /root/.cache/kagglehub/datasets/sgpjesus/bank-account-fraud-dataset-neurips-2022/versions/2

# %% [markdown]
# ## STEP 5 — Copy Dataset Into data Folder

# %%
import shutil
import os

source_file = os.path.join(path, "Base.csv")
destination_file = "data/Base.csv"

shutil.copy(source_file, destination_file)

print("Dataset copied successfully!")
# Out:
# Dataset copied successfully!

# %% [markdown]
# ## STEP 6 — Verify Dataset Loads

# %%
import pandas as pd

df = pd.read_csv("data/Base.csv")

print("Shape:", df.shape)
df.head()
# Out:
# Shape: (1000000, 32)
#    fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0           0     0.3               0.986506                         -1
# 1           0     0.8               0.617426                         -1
# 2           0     0.8               0.996707                          9
# 3           0     0.6               0.475100                         11
# 4           0     0.9               0.842307                         -1
#
#    current_address_months_count  customer_age  days_since_request  \
# 0                            25            40            0.006735
# 1                            89            20            0.010095
# 2                            14            40            0.012316
# 3                            14            30            0.006991
# 4                            29            40            5.742626
#
#    intended_balcon_amount payment_type  zip_count_4w  ...  has_other_cards  \
# ...
